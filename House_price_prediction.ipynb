# %% [markdown]
# # House Price Prediction

# %% [markdown]
# # By Shri Krishna

# %% [markdown]
# In this project, we are going to build a model that predict the house price in King County, Washington State, USA after carefully analysing and deriving insights from various features of kc_house_data.csv using Python language on Jupyter Notebook I.D.E.
#
# We use with Gradient Boosting Regressor algorithm make the prediction other regression algorithms like linear regression can be used to compare accuracy of model.
#
# First we will retrieve dataset in csv format from Kaggle. Now we will analyse the dataset using python analysis techniques and libraries(Pandas,Matplotlib,Seaborn,etc.)

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Importing dataset

# %%
data = pd.read_csv("kc_house_data.csv")

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
data['bedrooms'].value_counts().plot(kind='bar')
plt.title('number of Bedrooms')
plt.xlabel('Bedrooms')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.figure(figsize=(10,10))
sns.jointplot(x=data.lat.values, y=data.long.values, size=10)
plt.ylabel('Longitude', fontsize=12)
plt.xlabel('Latitude', fontsize=12)
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter(data.price,data.sqft_living)
plt.ylabel("Price")
plt.xlabel('Square feet')
plt.title("Price vs Square Feet")
# Out:
# Text(0.5, 1.0, 'Price vs Square Feet')

# %%
plt.scatter(data.price,data.lat)
plt.xlabel("Price")
plt.ylabel('Latitude')
plt.title("Latitude vs Price")
# Out:
# Text(0.5, 1.0, 'Latitude vs Price')

# %%
plt.scatter(data.bedrooms,data.price)
plt.title("Bedroom and Price ")
plt.xlabel("Bedrooms")
plt.ylabel("Price")
plt.show()
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
train1 = data.drop(['id', 'price'],axis=1)

# %%
train1.head()
# Out:
#               date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  20141013T000000         3       1.00         1180      5650     1.0
# 1  20141209T000000         3       2.25         2570      7242     2.0
# 2  20150225T000000         2       1.00          770     10000     1.0
# 3  20141209T000000         4       3.00         1960      5000     1.0
# 4  20150218T000000         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %% [markdown]
# # Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
labels = data['price']
conv_dates = [1 if values == 2014 else 0 for values in data.date ]
data['date'] = conv_dates
train1 = data.drop(['id', 'price'],axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(train1 , labels , test_size = 0.10,random_state =2)

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Accuracy of Linear Regression

# %%
reg.score(x_test,y_test)
# Out:
# 0.7320342760357638

# %% [markdown]
# # Gradient Boosting Regressor Model

# %%
from sklearn import ensemble
gbr = ensemble.GradientBoostingRegressor(n_estimators = 200, max_depth = 10, min_samples_split = 2,
          learning_rate = 0.1, loss = 'ls')

# %%
gbr.fit(x_train, y_train)
# Out:
# c:\users\skris\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\_gb.py:290: FutureWarning: The loss 'ls' was deprecated in v1.0 and will be removed in version 1.2. Use 'squared_error' which is equivalent.
#   FutureWarning,
# GradientBoostingRegressor(loss='ls', max_depth=10, n_estimators=200)

# %% [markdown]
# # Accuracy of GBR

# %%
gbr.score(x_test,y_test)
# Out:
# 0.9094721522827934

# %% [markdown]
# # Predictions using GBR

# %%
y_pred=gbr.predict(x_test)

# %%
y_pred
# Out:
# array([ 712843.96857979, 1405621.63280882,  440640.68198943, ...,
#         253495.54293105,  257129.56465713,  518132.26405942])

# %%
x_test[0:4]
# Out:
#       date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 6638     0         4       2.25         2410      4250     1.5           0
# 7366     0         3       1.50         2170     16600     1.0           1
# 3158     0         2       1.00         1450      6380     1.0           0
# 9117     0         5       3.25         4500      9648     2.0           0
#
#       view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 6638     0          5      7        1460            950      1929
# 7366     2          3     10        1130           1040      1979
# 3158     0          3      7        1450              0      1967
# 9117     4          4      8        3000           1500      1968
#
#       yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 6638             0    98117  47.6849 -122.376           1360        5074
# 7366             0    98052  47.6307 -122.088           3130       13875
# ...

# %%
y_pred=gbr.predict(x_test[0:4])

# %%
y_pred
# Out:
# array([ 712843.96857979, 1405621.63280882,  440640.68198943,
#         872262.94751332])
